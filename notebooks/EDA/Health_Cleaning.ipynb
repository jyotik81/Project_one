# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
file_path = Path('./Tables/health/13100096.csv')
mental = pd.read_csv(file_path)
mental.head()
# Out:
#    REF_DATE                             GEO DGUID                 Age group  \
# 0      2015  Canada (excluding territories)   NaN  Total, 12 years and over
# 1      2015  Canada (excluding territories)   NaN  Total, 12 years and over
# 2      2015  Canada (excluding territories)   NaN  Total, 12 years and over
# 3      2015  Canada (excluding territories)   NaN  Total, 12 years and over
# 4      2015  Canada (excluding territories)   NaN  Total, 12 years and over
#
#           Sex                                Indicators  \
# 0  Both sexes  Perceived health, very good or excellent
# 1  Both sexes  Perceived health, very good or excellent
# 2  Both sexes  Perceived health, very good or excellent
# 3  Both sexes  Perceived health, very good or excellent
# 4  Both sexes  Perceived health, very good or excellent
#
#                                    Characteristics      UOM  UOM_ID  \
# 0                                Number of persons   Number     223
# 1   Low 95% confidence interval, number of persons   Number     223
# 2  High 95% confidence interval, number of persons   Number     223
# 3                                          Percent  Percent     239
# 4             Low 95% confidence interval, percent  Percent     239
#
#   SCALAR_FACTOR  SCALAR_ID      VECTOR COORDINATE       VALUE STATUS  SYMBOL  \
# 0         units          0  v110787543  1.1.1.1.1  18759800.0    NaN     NaN
# 1         units          0  v110787544  1.1.1.1.2  18556100.0    NaN     NaN
# 2         units          0  v110787545  1.1.1.1.3  18963600.0    NaN     NaN
# 3         units          0  v110787546  1.1.1.1.4        61.9    NaN     NaN
# 4         units          0  v110787547  1.1.1.1.5        61.3    NaN     NaN
#
#    TERMINATED  DECIMALS
# 0         NaN         0
# 1         NaN         0
# 2         NaN         0
# 3         NaN         1
# 4         NaN         1

# %%
# clean the unnecessary collumns
mental = mental.drop(['DGUID','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'], axis=1)
mental.head()
# Out:
#    REF_DATE                             GEO                 Age group  \
# 0      2015  Canada (excluding territories)  Total, 12 years and over
# 1      2015  Canada (excluding territories)  Total, 12 years and over
# 2      2015  Canada (excluding territories)  Total, 12 years and over
# 3      2015  Canada (excluding territories)  Total, 12 years and over
# 4      2015  Canada (excluding territories)  Total, 12 years and over
#
#           Sex                                Indicators  \
# 0  Both sexes  Perceived health, very good or excellent
# 1  Both sexes  Perceived health, very good or excellent
# 2  Both sexes  Perceived health, very good or excellent
# 3  Both sexes  Perceived health, very good or excellent
# 4  Both sexes  Perceived health, very good or excellent
#
#                                    Characteristics       VALUE
# 0                                Number of persons  18759800.0
# 1   Low 95% confidence interval, number of persons  18556100.0
# 2  High 95% confidence interval, number of persons  18963600.0
# 3                                          Percent        61.9
# 4             Low 95% confidence interval, percent        61.3

# %%
#Filter by Characteristics
caract_filter = mental['Characteristics'] == 'Number of persons'
mental = mental.loc[caract_filter]
mental = mental.drop(['Characteristics'], axis=1)

# %%
#Filter by Sex - Exclude both sexes
sex_filter = mental['Sex'] != 'Both sexes'
mental = mental.loc[sex_filter]

# %%
#Filter only Provinces
geo_filter = mental['GEO'] != 'Canada (excluding territories)'
mental = mental.loc[geo_filter]

# %%
#Filter date between 2002 and 2012
date_filter = (mental['REF_DATE']>2016)
mental = mental.loc[date_filter]
mental.head()
# Out:
#        REF_DATE                        GEO                 Age group    Sex  \
# 75384      2017  Newfoundland and Labrador  Total, 12 years and over  Males
# 75392      2017  Newfoundland and Labrador  Total, 12 years and over  Males
# 75400      2017  Newfoundland and Labrador  Total, 12 years and over  Males
# 75408      2017  Newfoundland and Labrador  Total, 12 years and over  Males
# 75416      2017  Newfoundland and Labrador  Total, 12 years and over  Males
#
#                                               Indicators     VALUE
# 75384           Perceived health, very good or excellent  132700.0
# 75392                     Perceived health, fair or poor   24700.0
# 75400    Perceived mental health, very good or excellent  153200.0
# 75408              Perceived mental health, fair or poor   14500.0
# 75416  Perceived life stress, most days quite a bit o...   31700.0

# %%
mental['Age group'].value_counts()
# Out:
# Total, 12 years and over    2720
# 18 to 34 years              2520
# 35 to 49 years              2520
# 50 to 64 years              2520
# 65 years and over           2520
# 12 to 17 years              2420
# Name: Age group, dtype: int64

# %%
#Filter Age
age_filter = mental['Age group'].isin(['18 to 34 years', '35 to 49 years','50 to 64 years','65 years and over'])
mental = mental.loc[age_filter]
mental.head(20)
# Out:
#        REF_DATE                        GEO       Age group    Sex  \
# 76560      2017  Newfoundland and Labrador  18 to 34 years  Males
# 76568      2017  Newfoundland and Labrador  18 to 34 years  Males
# 76576      2017  Newfoundland and Labrador  18 to 34 years  Males
# 76584      2017  Newfoundland and Labrador  18 to 34 years  Males
# 76592      2017  Newfoundland and Labrador  18 to 34 years  Males
# 76600      2017  Newfoundland and Labrador  18 to 34 years  Males
# 76608      2017  Newfoundland and Labrador  18 to 34 years  Males
# 76616      2017  Newfoundland and Labrador  18 to 34 years  Males
# 76624      2017  Newfoundland and Labrador  18 to 34 years  Males
# 76632      2017  Newfoundland and Labrador  18 to 34 years  Males
# 76640      2017  Newfoundland and Labrador  18 to 34 years  Males
# 76648      2017  Newfoundland and Labrador  18 to 34 years  Males
# 76656      2017  Newfoundland and Labrador  18 to 34 years  Males
# 76664      2017  Newfoundland and Labrador  18 to 34 years  Males
# 76672      2017  Newfoundland and Labrador  18 to 34 years  Males
# 76680      2017  Newfoundland and Labrador  18 to 34 years  Males
# 76688      2017  Newfoundland and Labrador  18 to 34 years  Males
# 76696      2017  Newfoundland and Labrador  18 to 34 years  Males
# 76704      2017  Newfoundland and Labrador  18 to 34 years  Males
# 76712      2017  Newfoundland and Labrador  18 to 34 years  Males
#
#                                               Indicators    VALUE
# 76560           Perceived health, very good or excellent  32400.0
# 76568                     Perceived health, fair or poor   4700.0
# 76576    Perceived mental health, very good or excellent  36300.0
# 76584              Perceived mental health, fair or poor   5700.0
# 76592  Perceived life stress, most days quite a bit o...   8500.0
# 76600  Body mass index, adjusted self-reported, adult...  16600.0
# 76608  Body mass index, adjusted self-reported, adult...  14000.0
# 76616                      Arthritis (15 years and over)      NaN
# 76624                                           Diabetes      NaN
# 76632                                             Asthma      NaN
# 76640  Chronic obstructive pulmonary disease (COPD; 3...      NaN
# 76648                                High blood pressure      NaN
# 76656                                      Mood disorder      NaN
# 76664                Current smoker, daily or occasional  14300.0
# 76672                              Current smoker, daily  10900.0
# 76680                                     Heavy drinking  21300.0
# 76688  Self-reported physical activity, 150 minutes p...  34100.0
# 76696  Fruit and vegetable consumption, 5 times or mo...   7000.0
# 76704  Sense of belonging to local community, somewha...  32400.0
# 76712     Life satisfaction, satisfied or very satisfied  46800.0

# %%
mental['Age group']=mental['Age group'].replace({'18 to 34 years': 1})
mental['Age group']=mental['Age group'].replace({'35 to 49 years': 2})
mental['Age group']=mental['Age group'].replace({'50 to 64 years': 3})
mental['Age group']=mental['Age group'].replace({'65 years and over': 4})
mental.head(10)
# Out:
#        REF_DATE                        GEO  Age group    Sex  \
# 76560      2017  Newfoundland and Labrador          1  Males
# 76568      2017  Newfoundland and Labrador          1  Males
# 76576      2017  Newfoundland and Labrador          1  Males
# 76584      2017  Newfoundland and Labrador          1  Males
# 76592      2017  Newfoundland and Labrador          1  Males
# 76600      2017  Newfoundland and Labrador          1  Males
# 76608      2017  Newfoundland and Labrador          1  Males
# 76616      2017  Newfoundland and Labrador          1  Males
# 76624      2017  Newfoundland and Labrador          1  Males
# 76632      2017  Newfoundland and Labrador          1  Males
#
#                                               Indicators    VALUE
# 76560           Perceived health, very good or excellent  32400.0
# 76568                     Perceived health, fair or poor   4700.0
# 76576    Perceived mental health, very good or excellent  36300.0
# 76584              Perceived mental health, fair or poor   5700.0
# 76592  Perceived life stress, most days quite a bit o...   8500.0
# 76600  Body mass index, adjusted self-reported, adult...  16600.0
# 76608  Body mass index, adjusted self-reported, adult...  14000.0
# 76616                      Arthritis (15 years and over)      NaN
# 76624                                           Diabetes      NaN
# 76632                                             Asthma      NaN

# %%
#Filter Reason 'Permanent layoff'
mental_final = mental.groupby(['REF_DATE','GEO','Sex','Age group','Indicators'])['VALUE'].sum()
mental_final = pd.DataFrame(mental_final)
mental_final.head(20)
# Out:
#                                                                                           VALUE
# REF_DATE GEO     Sex     Age group Indicators
# 2017     Alberta Females 1         Arthritis (15 years and over)                        14300.0
#                                    Asthma                                               50600.0
#                                    Body mass index, adjusted self-reported, adult ...   82500.0
#                                    Body mass index, adjusted self-reported, adult ...  112700.0
#                                    Breast milk feeding initiation                      133500.0
#                                    Chronic obstructive pulmonary disease (COPD; 35...       0.0
#                                    Contact with a medical doctor in the past 12 mo...       0.0
#                                    Current smoker, daily                                43900.0
#                                    Current smoker, daily or occasional                  82600.0
#                                    Diabetes                                              6800.0
#                                    Exclusive breastfeeding, at least 6 months           46700.0
#                                    Fruit and vegetable consumption, 5 times or mor...  156700.0
#                                    Has a regular healthcare provider                   432500.0
#                                    Heavy drinking                                      128800.0
#                                    High blood pressure                                      0.0
#                                    Influenza immunization in the past 12 months        169200.0
#                                    Life satisfaction, satisfied or very satisfied      493900.0
#                                    Mood disorder                                        72300.0
#                                    Perceived health, fair or poor                       35200.0
#                                    Perceived health, very good or excellent            359700.0

# %%
mental_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 10080 entries, (2017, 'Alberta', 'Females', 1, 'Arthritis (15 years and over)') to (2021, 'Saskatchewan', 'Males', 4, 'Sense of belonging to local community, somewhat strong or very strong')
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   VALUE   10080 non-null  float64
# dtypes: float64(1)
# memory usage: 128.6+ KB

# %%
mental_final.to_csv('./Tables/health_final.csv', index=True)
